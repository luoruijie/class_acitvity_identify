# %%
import pandas as pd

# %%
# 读取两个CSV文件
file1 = 'combined_file_splited_old.xlsx'
file2 = 'combined_file_splited_new.xlsx'

# 使用pandas读取CSV文件
df1 = pd.read_excel(file1)
df2 = pd.read_excel(file2)

# 合并两个DataFrame

df_combined = pd.concat([df1, df2])

# 保存合并后的文件
output_file = 'combined_file_splited.xlsx'
df_combined.to_excel(output_file, index=False)

# %%
df_combined
# Out:
#                            file_name  \
# 0           gpt4o_705_evaluated.xlsx
# 1           gpt4o_705_evaluated.xlsx
# 2           gpt4o_705_evaluated.xlsx
# 3           gpt4o_705_evaluated.xlsx
# 4           gpt4o_705_evaluated.xlsx
# ..                               ...
# 281  gpt4o_静夜思_processed_output.xlsx
# 282  gpt4o_静夜思_processed_output.xlsx
# 283  gpt4o_静夜思_processed_output.xlsx
# 284  gpt4o_静夜思_processed_output.xlsx
# 285  gpt4o_静夜思_processed_output.xlsx
#
#                                                   text  \
# 0                                          直接在课文上批注出来，
# 1                               并概括义。你认为谁是最可爱的人结着原文分析，
# 2                                       第一个问题解决了没有？分层，
# 3    然后概括诚意五分钟的时间。这已经是我们第次次学篇文章章网课课期间，杰杰师师这篇文章的是吧？所...
# 4         请你来讲讲你的想法，你怎么分的，对，分层就分分段落分层次。呃，我是这样分的，一二三段呢，
# ..                                                 ...
# 281        那么我们来看一下这些商，大来看好了，希听好老师的要求而找一找我们上下结构的绳子有哪些，
# 282  大家有没有找到，啊，是上下结构，还有哪个组哪些字，哦，钱钱还有哪些字，汪对好，那么这节课老师...
# 283                                          这个字是什么结构，
# 284  尤其要注意了，这一笔的竖。还有这一笔的横，它是正好是落在竖中线和横中线的位置上，而且滋的上的...
# 285  卧钩卧钩卧钩卧钩卧钩。在上个学期我们学过了它的写法，而且它要与一个笔画要进行区别。这个笔画它...
#
#                                  gpt4o_output_analysis  \
# 0    分析过程：在这段话语中，“在课文上批注出来”体现出老师发起了一个开展课堂活动的指令。首先，“...
# 1    分析过程：在这段话语中，“并概括义。你认为谁是最可爱的人结着原文分析”体现出老师发起了一个开...
# 2    分析过程：在这段话语中，“第一个问题解决了没有？”体现出老师在询问学生第一个问题是否已经解决...
# 3    分析过程：在这段话语中，”我就请同学来回答啊“体现出老师发起了一个开展课堂活动的指令，邀请一...
# 4    分析过程：在这段话语中，“请你来讲讲你的想法”体现出老师发起了一个开展课堂活动的指令，邀请一...
# ..                                                 ...
# 281  分析过程：在这段话语中，“找一找我们上下结构的绳子有哪些”体现出老师发起了一个开展课堂活动的...
# 282  分析过程：在这段话语中，“大家有没有找到”结合前面的“上下结构”和“还有哪个组哪些字”这些话...
# 283  分析过程：在这段话语中，“这个字是什么结构”体现出老师发起了一个开展课堂活动的指令，要求学生...
# 284  分析过程：在这段话语中，“尤其要注意了，这一笔的竖。还有这一笔的横”体现出老师在详细讲解笔画...
# 285  分析过程：在这段话语中，老师首先回顾了一个叫做“卧钩”的笔画，并讨论了其写法。另外一句“它要...
#
#                                      gpt4o_output_json gpt4o_label
# 0    { "label": "独立练习", "status": "开始", "key_text":...        独立练习
# 1    { "label": "个体发言", "status": "开始", "key_text":...        个体发言
# 2    { "label": "NA", "status": "NA", "key_text": "...         NaN
# 3    { "label": "个体发言", "status": "开始", "key_text":...        个体发言
# 4    { "label": "个体发言", "status": "开始", "key_text":...        个体发言
# ..                                                 ...         ...
# 281  {   "label": "独立练习",   "status": "开始",   "key_...        独立练习
# 282  {   "label": "学生齐写",   "status": "开始",   "key_...        学生齐写
# 283  {   "label": "NA",   "status": "NA",   "key_te...         NaN
# 284  {   "label": "NA",   "status": "NA",   "key_te...         NaN
# 285  {   "label": "NA",   "status": "NA",   "key_te...         NaN
#
# [986 rows x 5 columns]
